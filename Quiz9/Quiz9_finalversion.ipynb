# %% [markdown]
# <a href="https://colab.research.google.com/github/JahnaviRamagiri/EVA-B2/blob/master/Quiz9/Quiz9_finalversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #used modules for data.py, train.py, test.py, Albtransform.py, summary2.py, utils,classifier.py

# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

cuda = torch.cuda.is_available()
print("CUDA Available?", cuda)

# For Reproducibility
torch.manual_seed(1)

if cuda:
    torch.cuda.manual_seed(1)
print(torch.cuda.get_device_name(0))

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# Out:
# CUDA Available? True
# Tesla P100-PCIE-16GB

# %%
# new code for assignment
from datetime import datetime
print("Current Date/Time: ", datetime.now())
# Out:
# Current Date/Time:  2020-05-30 11:26:05.058936

# %%
import Albtransform

import data
train_loader, test_loader = data.loader(128)
data.display()
# Out:
# got here
# CUDA Available? True
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import QuizDNN as m

# %%
# !pip install torchsummary
import summary2 as summary
summary.summ(device)
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#               ReLU-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#            Dropout-4           [-1, 64, 32, 32]               0
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#               ReLU-6           [-1, 64, 32, 32]               0
#        BatchNorm2d-7           [-1, 64, 32, 32]             128
#            Dropout-8           [-1, 64, 32, 32]               0
#             Conv2d-9           [-1, 64, 32, 32]          36,864
#              ReLU-10           [-1, 64, 32, 32]               0
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#           Dropout-12           [-1, 64, 32, 32]               0
#         MaxPool2d-13           [-1, 64, 16, 16]               0
#            Conv2d-14           [-1, 64, 16, 16]          36,864
#              ReLU-15           [-1, 64, 16, 16]               0
#       BatchNorm2d-16           [-1, 64, 16, 16]             128
#           Dropout-17           [-1, 64, 16, 16]               0
#            Conv2d-18           [-1, 64, 16, 16]          36,864
#              ReLU-19           [-1, 64, 16, 16]               0
#       BatchNorm2d-20           [-1, 64, 16, 16]             128
#           Dropout-21           [-1, 64, 16, 16]               0
#            Conv2d-22           [-1, 64, 16, 16]          36,864
#              ReLU-23           [-1, 64, 16, 16]               0
#       BatchNorm2d-24           [-1, 64, 16, 16]             128
#           Dropout-25           [-1, 64, 16, 16]               0
#         MaxPool2d-26             [-1, 64, 8, 8]               0
#            Conv2d-27             [-1, 64, 8, 8]          36,864
#              ReLU-28             [-1, 64, 8, 8]               0
#       BatchNorm2d-29             [-1, 64, 8, 8]             128
#           Dropout-30             [-1, 64, 8, 8]               0
#            Conv2d-31             [-1, 64, 8, 8]          36,864
#              ReLU-32             [-1, 64, 8, 8]               0
#       BatchNorm2d-33             [-1, 64, 8, 8]             128
#           Dropout-34             [-1, 64, 8, 8]               0
#            Conv2d-35             [-1, 64, 8, 8]          36,864
#              ReLU-36             [-1, 64, 8, 8]               0
#       BatchNorm2d-37             [-1, 64, 8, 8]             128
#           Dropout-38             [-1, 64, 8, 8]               0
# AdaptiveAvgPool2d-39             [-1, 64, 1, 1]               0
#            Conv2d-40             [-1, 10, 1, 1]             640
# ================================================================
# Total params: 298,432
# Trainable params: 298,432
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 8.03
# Params size (MB): 1.14
# Estimated Total Size (MB): 9.18
# ----------------------------------------------------------------

# %%
import train as tr
import test as te

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR


model = m.Net().to(device)

#model = Net().to(device)


optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
#scheduler = StepLR(optimizer, step_size= 10, gamma= 0.1)
epochs = 10

for epoch in range(epochs):
  print('EPOCH: ', epoch+1)
  tr.train(model, device, train_loader, optimizer, epoch)
  #scheduler.step()
  te.test(model, device, test_loader)
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH:  1
# Loss=1.2579033374786377 Batch_id=390 Accuracy=48.91: 100%|██████████| 391/391 [00:13<00:00, 29.16it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0093, Accuracy: 5786/10000 (57.86%)
#
# EPOCH:  2
# Loss=0.9908615946769714 Batch_id=390 Accuracy=65.00: 100%|██████████| 391/391 [00:13<00:00, 29.34it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0081, Accuracy: 6280/10000 (62.80%)
#
# EPOCH:  3
# Loss=0.7185946702957153 Batch_id=390 Accuracy=71.12: 100%|██████████| 391/391 [00:13<00:00, 29.53it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0062, Accuracy: 7207/10000 (72.07%)
#
# EPOCH:  4
# Loss=0.5788341760635376 Batch_id=390 Accuracy=75.01: 100%|██████████| 391/391 [00:13<00:00, 29.55it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0054, Accuracy: 7584/10000 (75.84%)
#
# EPOCH:  5
# Loss=0.5128928422927856 Batch_id=390 Accuracy=78.19: 100%|██████████| 391/391 [00:13<00:00, 29.34it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0051, Accuracy: 7734/10000 (77.34%)
#
# EPOCH:  6
# Loss=0.46590691804885864 Batch_id=390 Accuracy=80.04: 100%|██████████| 391/391 [00:13<00:00, 29.49it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0050, Accuracy: 7809/10000 (78.09%)
#
# EPOCH:  7
# Loss=0.7188896536827087 Batch_id=390 Accuracy=81.51: 100%|██████████| 391/391 [00:13<00:00, 29.44it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 7968/10000 (79.68%)
#
# EPOCH:  8
# Loss=0.5534278750419617 Batch_id=390 Accuracy=82.74: 100%|██████████| 391/391 [00:13<00:00, 29.34it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0056, Accuracy: 7635/10000 (76.35%)
#
# EPOCH:  9
# Loss=0.2947191894054413 Batch_id=390 Accuracy=83.91: 100%|██████████| 391/391 [00:13<00:00, 29.27it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0041, Accuracy: 8260/10000 (82.60%)
#
# EPOCH:  10
# Loss=0.47705286741256714 Batch_id=390 Accuracy=84.81: 100%|██████████| 391/391 [00:13<00:00, 29.38it/s]
# Test set: Average loss: 0.0039, Accuracy: 8259/10000 (82.59%)

# %%
import utilis as ut

path = '/content/classifier.pt'
saved_model = m.Net().to(device)
saved_model.load_state_dict(torch.load(path))
saved_model.eval()
ut.mis(saved_model, device, test_loader, 25)
# Out:
# Test set: Average loss: -7.2611, Accuracy: 8260/10000 (82.60%)
#
# (1740, 32, 32, 3)

# %%
ut.graph()

# %%
ut.testvtrain()
